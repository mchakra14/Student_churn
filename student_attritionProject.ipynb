# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Setting the working directory
os.chdir("C:\\Users\\RetailAdmin\\Desktop\\STUDY MATERIAL JIGSAW\\Capstone project\\Capstone project in python")
os.getcwd()
# Out:
# 'C:\\Users\\RetailAdmin\\Desktop\\STUDY MATERIAL JIGSAW\\Capstone project\\Capstone project in python'

# %%
# Reading the csv, xlsx file
stud=pd.read_excel("Student Applications & Performance.xlsx",na_values=[""," ","N/A","NA"])

# %%
# It gives number of Rows and columns
stud.shape
# Out:
# (3400, 56)

# %%
stud.shape[0]
# Out:
# 3400

# %%
# It shows first five rows of data
stud.head()
# Out:
#    STUDENT IDENTIFIER  STDNT_AGE STDNT_GENDER STDNT_BACKGROUND IN_STATE_FLAG  \
# 0             7808615         18            F            BGD 1             Y
# 1             7830063         19            F            BGD 1             N
# 2             7847538         18            M            BGD 1             Y
# 3             8006429         18            M            BGD 1             Y
# 4             7962680         18            F            BGD 1             Y
#
#   INTERNATIONAL_STS  STDNT_MAJOR STDNT_MINOR  STDNT_TEST_ENTRANCE1  \
# 0                 N   Undeclared           N                   NaN
# 1                 N   Undeclared           N                  26.0
# 2                 N  Mathematics           N                   NaN
# 3                 N   Undeclared           N                   NaN
# 4                 N          Art           N                   NaN
#
#    STDNT_TEST_ENTRANCE2  ...  DEGREE_GROUP_CD  DEGREE_GROUP_DESC  \
# ...

# %%
# Its gives information of all the data characteristics into int , object and float
stud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3400 entries, 0 to 3399
# Data columns (total 56 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   STUDENT IDENTIFIER        3400 non-null   int64
#  1   STDNT_AGE                 3400 non-null   int64
#  2   STDNT_GENDER              3400 non-null   object
#  3   STDNT_BACKGROUND          3400 non-null   object
#  4   IN_STATE_FLAG             3400 non-null   object
#  5   INTERNATIONAL_STS         3400 non-null   object
#  6   STDNT_MAJOR               3400 non-null   object
#  7   STDNT_MINOR               3400 non-null   object
#  8   STDNT_TEST_ENTRANCE1      1106 non-null   float64
#  9   STDNT_TEST_ENTRANCE2      2492 non-null   float64
#  10  STDNT_TEST_ENTRANCE_COMB  2882 non-null   float64
#  11  FIRST_TERM                3400 non-null   int64
#  12  CORE_COURSE_NAME_1_F      3400 non-null   object
# ...

# %%
#No of unique values per column 
for column in stud.columns:
    print(f"{column}: Number of unique values {stud[column].nunique()}")
    print("==========================================================")
# Out:
# STUDENT IDENTIFIER: Number of unique values 3400
# ...
# STDNT_AGE: Number of unique values 11
# ...
# STDNT_GENDER: Number of unique values 2
# ...
# STDNT_BACKGROUND: Number of unique values 8
# ...
# IN_STATE_FLAG: Number of unique values 2
# ...
# INTERNATIONAL_STS: Number of unique values 2
# ...
# STDNT_MAJOR: Number of unique values 54
# ...
# STDNT_MINOR: Number of unique values 37
# ...
# STDNT_TEST_ENTRANCE1: Number of unique values 23
# ...
# STDNT_TEST_ENTRANCE2: Number of unique values 109
# ...
# STDNT_TEST_ENTRANCE_COMB: Number of unique values 24
# ...
# FIRST_TERM: Number of unique values 6
# ...
# CORE_COURSE_NAME_1_F: Number of unique values 69
# ...
# CORE_COURSE_GRADE_1_F: Number of unique values 7
# ...
# CORE_COURSE_NAME_2_F: Number of unique values 74
# ...
# CORE_COURSE_GRADE_2_F: Number of unique values 7
# ...
# CORE_COURSE_NAME_3_F: Number of unique values 74
# ...
# CORE_COURSE_GRADE_3_F: Number of unique values 6
# ...
# CORE_COURSE_NAME_4_F: Number of unique values 68
# ...
# CORE_COURSE_GRADE_4_F: Number of unique values 6
# ...

# %% [markdown]
# STUDENT IDENTIFIER contains high number of unique values so we can drop it.

# %%
# It shows sum of missing values for each variables
stud.isnull().sum()
# Out:
# STUDENT IDENTIFIER             0
# STDNT_AGE                      0
# STDNT_GENDER                   0
# STDNT_BACKGROUND               0
# IN_STATE_FLAG                  0
# INTERNATIONAL_STS              0
# STDNT_MAJOR                    0
# STDNT_MINOR                    0
# STDNT_TEST_ENTRANCE1        2294
# STDNT_TEST_ENTRANCE2         908
# STDNT_TEST_ENTRANCE_COMB     518
# FIRST_TERM                     0
# CORE_COURSE_NAME_1_F           0
# CORE_COURSE_GRADE_1_F          0
# CORE_COURSE_NAME_2_F          99
# CORE_COURSE_GRADE_2_F         99
# CORE_COURSE_NAME_3_F         565
# CORE_COURSE_GRADE_3_F        565
# CORE_COURSE_NAME_4_F        1597
# CORE_COURSE_GRADE_4_F       1597
# CORE_COURSE_NAME_5_F        2755
# CORE_COURSE_GRADE_5_F       2755
# CORE_COURSE_NAME_6_F        3272
# CORE_COURSE_GRADE_6_F       3272
# SECOND_TERM                    0
# CORE_COURSE_NAME_1_S         157
# CORE_COURSE_GRADE_1_S        232
# CORE_COURSE_NAME_2_S         439
# ...

# %%
# high number of unique values hence droped
stud.drop(['STUDENT IDENTIFIER'], axis=1, inplace=True)

# %%
stud.columns
# Out:
# Index(['STDNT_AGE', 'STDNT_GENDER', 'STDNT_BACKGROUND', 'IN_STATE_FLAG',
#        'INTERNATIONAL_STS', 'STDNT_MAJOR', 'STDNT_MINOR',
#        'STDNT_TEST_ENTRANCE1', 'STDNT_TEST_ENTRANCE2',
#        'STDNT_TEST_ENTRANCE_COMB', 'FIRST_TERM', 'CORE_COURSE_NAME_1_F',
#        'CORE_COURSE_GRADE_1_F', 'CORE_COURSE_NAME_2_F',
#        'CORE_COURSE_GRADE_2_F', 'CORE_COURSE_NAME_3_F',
#        'CORE_COURSE_GRADE_3_F', 'CORE_COURSE_NAME_4_F',
#        'CORE_COURSE_GRADE_4_F', 'CORE_COURSE_NAME_5_F',
#        'CORE_COURSE_GRADE_5_F', 'CORE_COURSE_NAME_6_F',
#        'CORE_COURSE_GRADE_6_F', 'SECOND_TERM', 'CORE_COURSE_NAME_1_S',
#        'CORE_COURSE_GRADE_1_S', 'CORE_COURSE_NAME_2_S',
#        'CORE_COURSE_GRADE_2_S', 'CORE_COURSE_NAME_3_S',
#        'CORE_COURSE_GRADE_3_S', 'CORE_COURSE_NAME_4_S',
#        'CORE_COURSE_GRADE_4_S', 'CORE_COURSE_NAME_5_S',
#        'CORE_COURSE_GRADE_5_S', 'CORE_COURSE_NAME_6_S',
#        'CORE_COURSE_GRADE_6_S', 'HOUSING_STS', 'RETURNED_2ND_YR',
# ...

# %%
stud.skew()
# Out:
# STDNT_AGE                    4.416754
# STDNT_TEST_ENTRANCE1         0.671944
# STDNT_TEST_ENTRANCE2        -0.922564
# STDNT_TEST_ENTRANCE_COMB    -0.364692
# FIRST_TERM                  -0.170108
# SECOND_TERM                 -0.170108
# RETURNED_2ND_YR             -1.405151
# DISTANCE_FROM_HOME          18.439510
# HIGH_SCHL_GPA               -0.248503
# FATHER_HI_EDU_CD             0.192835
# MOTHER_HI_EDU_CD            -0.066167
# FIRST_TERM_ATTEMPT_HRS       0.380062
# FIRST_TERM_EARNED_HRS       -0.902359
# SECOND_TERM_ATTEMPT_HRS     -0.178607
# SECOND_TERM_EARNED_HRS      -0.891158
# GROSS_FIN_NEED               1.235763
# COST_OF_ATTEND               0.345186
# EST_FAM_CONTRIBUTION         3.815042
# UNMET_NEED                   0.665665
# dtype: float64

# %% [markdown]
# DISTANCE_FROM_HOME and STDNT_AGE are highly skewed.

# %%
#check percentiles for some columns
quan=[]
for i in list(range(1,101)):
    quan.append(i/100)
print(stud['DISTANCE_FROM_HOME'].quantile(q=quan).tail())
print(stud['STDNT_AGE'].quantile(q=quan).tail())
# Out:
# 0.96     208.0
# 0.97     235.0
# 0.98     275.0
# 0.99     666.0
# 1.00    5932.0
# Name: DISTANCE_FROM_HOME, dtype: float64
# 0.96    19.0
# 0.97    19.0
# 0.98    19.0
# 0.99    19.0
# 1.00    26.0
# Name: STDNT_AGE, dtype: float64

# %%
# it is group data with two different variables named under div
div=stud.groupby ('RETURNED_2ND_YR')

# %%
# it shows mean of all the variables wrt to 0 and 1
div.mean()
# Out:
#                  STDNT_AGE  STDNT_TEST_ENTRANCE1  STDNT_TEST_ENTRANCE2  \
# RETURNED_2ND_YR
# 0                18.015214             20.550000            970.705882
# 1                17.988420             20.690531            963.647830
#
#                  STDNT_TEST_ENTRANCE_COMB     FIRST_TERM    SECOND_TERM  \
# RETURNED_2ND_YR
# 0                              999.403974  200787.391425  200881.391425
# 1                              997.322212  200774.193500  200868.193500
#
#                  DISTANCE_FROM_HOME  HIGH_SCHL_GPA  FATHER_HI_EDU_CD  \
# RETURNED_2ND_YR
# 0                        112.214586       3.131802          2.527419
# 1                         96.506762       3.221768          2.569421
#
#                  MOTHER_HI_EDU_CD  FIRST_TERM_ATTEMPT_HRS  \
# RETURNED_2ND_YR
# 0                        2.535000               13.988935
# 1                        2.580701               13.985058
#
#                  FIRST_TERM_EARNED_HRS  SECOND_TERM_ATTEMPT_HRS  \
# ...

# %%
# It gives count for number of std left and return
stud.RETURNED_2ND_YR.value_counts()
# Out:
# 1    2677
# 0     723
# Name: RETURNED_2ND_YR, dtype: int64

# %%
stud['RETURNED_2ND_YR']=stud['RETURNED_2ND_YR'].map(lambda x: 1 if x== 0 else 0)

# %% [markdown]
# This function used to convert 0 to 1 and 1 to 0 in returned second year column, As we are trying to predict model for students who didnot return to second year.

# %%
stud.head(5)
# Out:
#    STDNT_AGE STDNT_GENDER STDNT_BACKGROUND IN_STATE_FLAG INTERNATIONAL_STS  \
# 0         18            F            BGD 1             Y                 N
# 1         19            F            BGD 1             N                 N
# 2         18            M            BGD 1             Y                 N
# 3         18            M            BGD 1             Y                 N
# 4         18            F            BGD 1             Y                 N
#
#    STDNT_MAJOR STDNT_MINOR  STDNT_TEST_ENTRANCE1  STDNT_TEST_ENTRANCE2  \
# 0   Undeclared           N                   NaN                1150.0
# 1   Undeclared           N                  26.0                   NaN
# 2  Mathematics           N                   NaN                1020.0
# 3   Undeclared           N                   NaN                1210.0
# 4          Art           N                   NaN                1200.0
#
#    STDNT_TEST_ENTRANCE_COMB  ...  DEGREE_GROUP_CD DEGREE_GROUP_DESC  \
# ...

# %%
# It will put the missing values in descending order with their percentage for each variable
misper_col=pd.DataFrame(round((stud.isnull().sum()/stud.shape[0])*100,2).sort_values(ascending=False)).reset_index()

# %%
# It shows the percentage of missing values in descending orders
misper_col
# Out:
#                        index      0
# 0       CORE_COURSE_NAME_6_S  97.62
# 1      CORE_COURSE_GRADE_6_S  97.62
# 2       CORE_COURSE_NAME_6_F  96.24
# 3      CORE_COURSE_GRADE_6_F  96.24
# 4      CORE_COURSE_GRADE_5_S  86.76
# 5       CORE_COURSE_NAME_5_S  86.76
# 6       CORE_COURSE_NAME_5_F  81.03
# 7      CORE_COURSE_GRADE_5_F  81.03
# 8       STDNT_TEST_ENTRANCE1  67.47
# 9       CORE_COURSE_NAME_4_S  60.15
# 10     CORE_COURSE_GRADE_4_S  60.15
# 11     CORE_COURSE_GRADE_4_F  46.97
# 12      CORE_COURSE_NAME_4_F  46.97
# 13      CORE_COURSE_NAME_3_S  30.53
# 14     CORE_COURSE_GRADE_3_S  30.53
# 15      STDNT_TEST_ENTRANCE2  26.71
# 16     CORE_COURSE_GRADE_3_F  16.62
# 17      CORE_COURSE_NAME_3_F  16.62
# 18  STDNT_TEST_ENTRANCE_COMB  15.24
# 19          MOTHER_HI_EDU_CD  14.38
# 20      CORE_COURSE_NAME_2_S  12.91
# 21     CORE_COURSE_GRADE_2_S  12.91
# 22          FATHER_HI_EDU_CD  12.71
# 23     CORE_COURSE_GRADE_1_S   6.82
# 24    SECOND_TERM_EARNED_HRS   6.15
# ...

# %%
# It will create new data frame for selected data,dropping columns which are above 20% 
drp=misper_col[0:16]

# %%
# It shows the data that we are not using for analysis
drp
# Out:
#                     index      0
# 0    CORE_COURSE_NAME_6_S  97.62
# 1   CORE_COURSE_GRADE_6_S  97.62
# 2    CORE_COURSE_NAME_6_F  96.24
# 3   CORE_COURSE_GRADE_6_F  96.24
# 4   CORE_COURSE_GRADE_5_S  86.76
# 5    CORE_COURSE_NAME_5_S  86.76
# 6    CORE_COURSE_NAME_5_F  81.03
# 7   CORE_COURSE_GRADE_5_F  81.03
# 8    STDNT_TEST_ENTRANCE1  67.47
# 9    CORE_COURSE_NAME_4_S  60.15
# 10  CORE_COURSE_GRADE_4_S  60.15
# 11  CORE_COURSE_GRADE_4_F  46.97
# 12   CORE_COURSE_NAME_4_F  46.97
# 13   CORE_COURSE_NAME_3_S  30.53
# 14  CORE_COURSE_GRADE_3_S  30.53
# 15   STDNT_TEST_ENTRANCE2  26.71

# %%
# new data frame created by name stud_final for drop by Name.this data frame is only for the student who left college
stud=stud.drop(drp['index'], axis=1)

# %%
# it gives size of the dataframe stud_left
stud.shape
# Out:
# (3400, 39)

# %%
# It will show null values for all columns in stud_left data frame
stud.isnull().sum()
# Out:
# STDNT_AGE                     0
# STDNT_GENDER                  0
# STDNT_BACKGROUND              0
# IN_STATE_FLAG                 0
# INTERNATIONAL_STS             0
# STDNT_MAJOR                   0
# STDNT_MINOR                   0
# STDNT_TEST_ENTRANCE_COMB    518
# FIRST_TERM                    0
# CORE_COURSE_NAME_1_F          0
# CORE_COURSE_GRADE_1_F         0
# CORE_COURSE_NAME_2_F         99
# CORE_COURSE_GRADE_2_F        99
# CORE_COURSE_NAME_3_F        565
# CORE_COURSE_GRADE_3_F       565
# SECOND_TERM                   0
# CORE_COURSE_NAME_1_S        157
# CORE_COURSE_GRADE_1_S       232
# CORE_COURSE_NAME_2_S        439
# CORE_COURSE_GRADE_2_S       439
# HOUSING_STS                   0
# RETURNED_2ND_YR               0
# DISTANCE_FROM_HOME           25
# HIGH_SCHL_GPA                53
# HIGH_SCHL_NAME                1
# FATHER_HI_EDU_CD            432
# FATHER_HI_EDU_DESC            0
# MOTHER_HI_EDU_CD            489
# MOTHER_HI_EDU_DESC            0
# ...

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
#Normalise distance from home column to treat skewness.Normalization converts all data points to decimals between 0 and 1. 
def normalize(column):
    upper = column.max()
    lower = column.min()
    y = (column - lower)/(upper-lower)
    return y
normalized = normalize(stud.DISTANCE_FROM_HOME)
normalized.describe()
# Out:
# count    3375.000000
# mean        0.016828
# std         0.039649
# min         0.000000
# 25%         0.011632
# 50%         0.011632
# 75%         0.023264
# max         1.000000
# Name: DISTANCE_FROM_HOME, dtype: float64

# %%
# Replace the null values with mean value
stud['STDNT_TEST_ENTRANCE_COMB'].fillna(stud['STDNT_TEST_ENTRANCE_COMB'].mean(),inplace=True)

# %%
stud['DISTANCE_FROM_HOME'].fillna(stud['DISTANCE_FROM_HOME'].mean(),inplace=True)

# %%
stud['HIGH_SCHL_GPA'].fillna(stud['HIGH_SCHL_GPA'].mean(),inplace=True)

# %%
stud['FATHER_HI_EDU_CD'].fillna(stud['FATHER_HI_EDU_CD'].mean(),inplace=True)

# %%
stud['MOTHER_HI_EDU_CD'].fillna(stud['MOTHER_HI_EDU_CD'].mean(),inplace=True)

# %%
stud['SECOND_TERM_EARNED_HRS'].fillna(stud['SECOND_TERM_EARNED_HRS'].mean(),inplace=True)

# %%
stud['SECOND_TERM_ATTEMPT_HRS'].fillna(stud['SECOND_TERM_ATTEMPT_HRS'].mean(),inplace=True)

# %%
# Replace the null values with mode value
stud['CORE_COURSE_NAME_2_F'].fillna(stud['CORE_COURSE_NAME_2_F'].mode().iloc[0],inplace=True)

# %%
stud['CORE_COURSE_GRADE_2_F'].fillna(stud['CORE_COURSE_GRADE_2_F'].mode().iloc[0],inplace=True)

# %%
stud['CORE_COURSE_NAME_3_F'].fillna(stud['CORE_COURSE_NAME_3_F'].mode().iloc[0],inplace=True)

# %%
stud['CORE_COURSE_GRADE_3_F'].fillna(stud['CORE_COURSE_GRADE_3_F'].mode().iloc[0],inplace=True)

# %%
stud['CORE_COURSE_GRADE_1_S'].fillna(stud['CORE_COURSE_GRADE_1_S'].mode().iloc[0],inplace=True)

# %%
stud['CORE_COURSE_GRADE_2_S'].fillna(stud['CORE_COURSE_GRADE_2_S'].mode().iloc[0],inplace=True)

# %%
stud['HIGH_SCHL_NAME'].fillna(stud['HIGH_SCHL_NAME'].mode().iloc[0],inplace=True)

# %%
# it will drop the coloumn which is not relevant for our analysis
stud.drop(columns='CORE_COURSE_NAME_1_S',axis=1,inplace=True)

# %%
stud.drop(columns='FATHER_HI_EDU_DESC',axis=1,inplace=True)

# %%
stud.drop(columns='MOTHER_HI_EDU_DESC',axis=1,inplace=True)

# %%
stud.drop(columns='DEGREE_GROUP_DESC',axis=1,inplace=True)

# %%
stud.drop(columns=['CORE_COURSE_NAME_2_S'],axis=1,inplace=True)

# %%
stud.isnull().sum()
# Out:
# STDNT_AGE                   0
# STDNT_GENDER                0
# STDNT_BACKGROUND            0
# IN_STATE_FLAG               0
# INTERNATIONAL_STS           0
# STDNT_MAJOR                 0
# STDNT_MINOR                 0
# STDNT_TEST_ENTRANCE_COMB    0
# FIRST_TERM                  0
# CORE_COURSE_NAME_1_F        0
# CORE_COURSE_GRADE_1_F       0
# CORE_COURSE_NAME_2_F        0
# CORE_COURSE_GRADE_2_F       0
# CORE_COURSE_NAME_3_F        0
# CORE_COURSE_GRADE_3_F       0
# SECOND_TERM                 0
# CORE_COURSE_GRADE_1_S       0
# CORE_COURSE_GRADE_2_S       0
# HOUSING_STS                 0
# RETURNED_2ND_YR             0
# DISTANCE_FROM_HOME          0
# HIGH_SCHL_GPA               0
# HIGH_SCHL_NAME              0
# FATHER_HI_EDU_CD            0
# MOTHER_HI_EDU_CD            0
# DEGREE_GROUP_CD             0
# FIRST_TERM_ATTEMPT_HRS      0
# FIRST_TERM_EARNED_HRS       0
# SECOND_TERM_ATTEMPT_HRS     0
# SECOND_TERM_EARNED_HRS      0
# GROSS_FIN_NEED              0
# ...

# %% [markdown]
# # Catagorical features

# %%
obj_col = []
for column in stud.columns:
    if len(stud[column].unique()) == 2:
        obj_col.append(column)
        print(f"{column} : {stud[column].unique()}")
        print(stud[column].value_counts())
        print("====================================")
obj_col.remove('RETURNED_2ND_YR')
# Out:
# STDNT_GENDER : ['F' 'M']
# F    2140
# M    1260
# Name: STDNT_GENDER, dtype: int64
# ...
# IN_STATE_FLAG : ['Y' 'N']
# Y    3063
# N     337
# Name: IN_STATE_FLAG, dtype: int64
# ...
# INTERNATIONAL_STS : ['N' 'Y']
# N    3373
# Y      27
# Name: INTERNATIONAL_STS, dtype: int64
# ...
# HOUSING_STS : ['On Campus' 'Off Campus']
# Off Campus    1981
# On Campus     1419
# Name: HOUSING_STS, dtype: int64
# ...
# RETURNED_2ND_YR : [1 0]
# 0    2677
# 1     723
# Name: RETURNED_2ND_YR, dtype: int64
# ...

# %% [markdown]
# #  Numerical Features

# %%
for column in stud.columns:
    print(f"{column}: Number of unique values {stud[column].nunique()}")
# Out:
# STDNT_AGE: Number of unique values 11
# STDNT_GENDER: Number of unique values 2
# STDNT_BACKGROUND: Number of unique values 8
# IN_STATE_FLAG: Number of unique values 2
# INTERNATIONAL_STS: Number of unique values 2
# STDNT_MAJOR: Number of unique values 54
# STDNT_MINOR: Number of unique values 37
# STDNT_TEST_ENTRANCE_COMB: Number of unique values 25
# FIRST_TERM: Number of unique values 6
# CORE_COURSE_NAME_1_F: Number of unique values 69
# CORE_COURSE_GRADE_1_F: Number of unique values 7
# CORE_COURSE_NAME_2_F: Number of unique values 74
# CORE_COURSE_GRADE_2_F: Number of unique values 7
# CORE_COURSE_NAME_3_F: Number of unique values 74
# CORE_COURSE_GRADE_3_F: Number of unique values 6
# SECOND_TERM: Number of unique values 6
# CORE_COURSE_GRADE_1_S: Number of unique values 8
# CORE_COURSE_GRADE_2_S: Number of unique values 6
# HOUSING_STS: Number of unique values 2
# RETURNED_2ND_YR: Number of unique values 2
# DISTANCE_FROM_HOME: Number of unique values 72
# ...

# %%
disc_col = []
for column in stud.columns:
    if 2 < stud[column].nunique() <= 20:
        print(f"{column} : {stud[column].unique()}")
        disc_col.append(column)
        print("====================================")
# Out:
# STDNT_AGE : [18 19 17 20 16 21 23 25 22 26 24]
# ...
# STDNT_BACKGROUND : ['BGD 1' 'BGD 3' 'BGD 6' 'BGD 4' 'BGD 8' 'BGD 2' 'BGD 7' 'BGD 5']
# ...
# FIRST_TERM : [200708 200808 201008 200508 200608 200908]
# ...
# CORE_COURSE_GRADE_1_F : ['A' 'B' 'C' 'NOT REP' 'D' 'F' 'INCOMPL']
# ...
# CORE_COURSE_GRADE_2_F : ['A' 'B' 'C' 'D' 'F' 'NOT REP' 'INCOMPL']
# ...
# CORE_COURSE_GRADE_3_F : ['A' 'B' 'C' 'D' 'F' 'INCOMPL']
# ...
# SECOND_TERM : [200802 200902 201102 200602 200702 201002]
# ...
# CORE_COURSE_GRADE_1_S : ['A' 'B' 'C' 'D' 'F' 'NOT REP' 'INCOMPL' 'Unknown']
# ...
# CORE_COURSE_GRADE_2_S : ['A' 'B' 'C' 'D' 'F' 'INCOMPL']
# ...
# FATHER_HI_EDU_CD : [2.5606469 3.        2.        1.        4.       ]
# ...
# MOTHER_HI_EDU_CD : [2.57128135 3.         4.         2.         1.        ]
# ...
# DEGREE_GROUP_CD : ['B' 'A' 'V']
# ...
# FIRST_TERM_ATTEMPT_HRS : [16 18 15 13 12 17 14 19 20 21  9 11]
# ...

# %%
len(disc_col)
# Out:
# 13

# %%
disc_col1 = []
for column in stud.columns:
    if 20 < stud[column].nunique() <= 100:
        print(f"{column} : {stud[column].unique()}")
        disc_col1.append(column)
        print("====================================")
# Out:
# STDNT_MAJOR : ['Undeclared' 'Mathematics' 'Art' 'Political Science' 'Biology'
#  'Accounting' 'Criminal Justice' 'Psychology' 'Theatre Arts' 'Nursing'
#  'Pre-Nursing' 'Chemistry' 'Pre-Engineering/RETP'
#  'Early Childhood Education' 'Music Performance'
#  'English Language/Literature' 'Joint Enrollment - Accel'
#  'History and Secondary Ed' 'History' 'Engineering Studies'
#  'Computer Science - Systems' 'Pre-Business' 'Management'
#  'Theatre Education' 'Marketing' 'Communication' 'Music Education'
#  'French with Teacher Cert' 'English and Secondary Ed' 'Exercise Science'
#  'General Business' 'Mathematics and Secondary Ed' 'Finance' 'French'
#  'Health Science' 'Spec Ed: Gen. Curr. - Reading' 'Music'
#  'Middle Grades Education' 'Geology' 'Management Information Systems'
#  'Art Education' 'Applied Computer Science' 'Information Technology'
#  'Sociology' 'Computer Science - Games' 'Spanish' 'General Studies/AS'
#  'Biology and Secondary Ed' 'Chemistry and Secondary Ed'
# ...

# %%
len(disc_col1)
# Out:
# 10

# %%
disc_col2 = []
for column in stud.columns:
    if stud[column].nunique() > 100:
        print(f"{column} : {stud[column].unique()}")
        disc_col2.append(column)
        print("====================================")
# Out:
# HIGH_SCHL_GPA : [4.         2.89       3.39       2.93       3.86       3.93
#  3.69       3.34       3.96       3.35       3.20273753 3.5
#  2.4        3.71       3.72       3.73       3.12       3.57
#  3.81       3.9        3.92       3.43       3.6        2.97
#  3.58       3.79       3.54       3.46       3.67       2.9
#  3.63       3.8        3.75       3.56       3.53       3.78
#  3.33       3.         3.61       3.3        3.21       3.37
#  2.66       3.82       3.62       2.88       3.87       3.88
#  3.26       3.7        3.74       2.8        2.63       3.47
#  3.52       3.68       3.25       3.28       3.06       3.66
#  3.64       3.4375     3.85       3.83       3.07       2.96
#  3.36       3.16       3.15       2.76       3.31       3.77
#  3.13       3.4        3.18       3.27       3.84       3.19
#  2.92       3.94       2.73       3.14       2.81       2.64
#  3.08       3.09       3.65       3.38       2.51       3.1
# ...

# %%
len(disc_col2)
# Out:
# 6

# %% [markdown]
# # Data Visualisation

# %%
plt.figure(figsize=(30, 30))

for i, column in enumerate(disc_col, 1):
    plt.subplot(6, 4, i)
    stud[stud["RETURNED_2ND_YR"] == 0][column].hist(bins=25,color='blue',label='Attrition-No',alpha=0.5)
    stud[stud["RETURNED_2ND_YR"] == 1][column].hist(bins=25,color='red',label='Attrition-Yes',alpha=1)
    plt.legend()
    plt.xlabel(column)

# %%
plt.figure(figsize=(30, 30))

for i, column in enumerate(disc_col1, 1):
    plt.subplot(5, 2, i)
    stud[stud["RETURNED_2ND_YR"] == 0][column].hist(bins=25,color='blue',label='Attrition-No',alpha=0.5)
    stud[stud["RETURNED_2ND_YR"] == 1][column].hist(bins=25,color='red',label='Attrition-Yes',alpha=1)
    plt.legend()
    plt.xlabel(column)

# %%
plt.figure(figsize=(30, 30))

for i, column in enumerate(disc_col2, 1):
    plt.subplot(3, 2, i)
    stud[stud["RETURNED_2ND_YR"] == 0][column].hist(bins=25,color='blue',label='Attrition-No',alpha=0.5)
    stud[stud["RETURNED_2ND_YR"] == 1][column].hist(bins=25,color='red',label='Attrition-Yes',alpha=1)
    plt.legend()
    plt.xlabel(column)

# %%
plt.figure(figsize=(20,10))

for i, column in enumerate(obj_col, 1):
    plt.subplot(2, 2, i)
    stud[stud["RETURNED_2ND_YR"] == 0][column].value_counts().plot.bar(color='blue',label='Attrition-No',alpha=0.5)
    stud[stud["RETURNED_2ND_YR"] == 1][column].value_counts().plot.bar(color='red',label='Attrition-Yes',alpha=1)
    plt.legend()
    plt.xlabel(column)

# %% [markdown]
# Above histogram analysis depicts the following:
#
# `STDNT_GENDER` - Female attrition is more.
#
# `EST_FAM_CONTRIBUTION` - Students having almost zero contribution attrited more.
#
# `HIGH_SCHL_GPA` - Attrition is more with GPA between 2.7-3.5
#
# `DISTANCE_FROM_HOME` - Within 150km attrition is more.
#
# `AGE` - Attrition is among 18yrs old students.
#
# `FIRST/SECOND TERM` - Attrition increased with year.

# %%
sns.boxplot(data=stud['DISTANCE_FROM_HOME'])
plt.title('DISTANCE_FROM_HOME')
plt.ylabel('DISTANCE FROM HOME')
# Out:
# Text(0, 0.5, 'DISTANCE FROM HOME')

# %%
sns.boxplot(data=stud['STDNT_AGE'])
plt.title('STDNT_AGE')
plt.ylabel('STDNT_AGE')
# Out:
# Text(0, 0.5, 'STDNT_AGE')

# %% [markdown]
# # CORRELATION BETWEEN VARIABLES

# %%
col=stud.corr().nlargest(10,"RETURNED_2ND_YR").RETURNED_2ND_YR.index
plt.figure(figsize=(15, 15))
sns.heatmap(stud[col].corr(), annot=True, cmap="RdYlGn", annot_kws={"size":10})

# %%
#get correlations of each features in dataset
corrmat = stud.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(stud[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# -`SECOND_TERM_EARNED_HRS` is negatively correlated with `RETURNED_SECOND_YEAR`
#
# -`UNMET_NEED` and `GROSS_FIN_NEED` are highly correlated to each other.
#
# -`FIRST_TERM` and `SECOND_TERM` are highly correlated.
#
# -`GROSS_FIN_NEED` and `COST_OF_ATTEND` are correlated.
#
# -`UNMET_NEED` and `EST_FAM_CONTRIBUTION` are highly negatively correlated.

# %%
stud.drop('RETURNED_2ND_YR', axis=1).corrwith(stud.RETURNED_2ND_YR).plot(kind='barh', figsize=(7, 7))

# %% [markdown]
# `RETURNED_SECOND_YEAR` is negatively correlated with `SECOND_TERM_EARNED_HRS`,`FIRST_TERM_EARNED_HRS`, `HIGH_SCHL_GPA` and `SECOND_TERM_ATTEMPT_HRS`

# %%
#drop GROSS_FIN_NEED and COST_OF_ATTEND as they are correlated.
stud.drop(columns='GROSS_FIN_NEED',axis=1,inplace=True)

# %%
stud.drop(columns='COST_OF_ATTEND',axis=1,inplace=True)

# %%
# drop SECOND_TERM as highly correaled to FIRST_TERM
stud.drop(columns='SECOND_TERM',axis=1,inplace=True)

# %% [markdown]
# # FEATURE SELECTION

# %% [markdown]
# Based on mean, correlation matrix and histogram given below features are selected as critical features for building predictive model

# %%
stud1 = stud[['RETURNED_2ND_YR','UNMET_NEED','EST_FAM_CONTRIBUTION',
         'DISTANCE_FROM_HOME','STDNT_GENDER','STDNT_AGE','HOUSING_STS','HIGH_SCHL_GPA',
        'STDNT_MAJOR','STDNT_MINOR','FIRST_TERM','FATHER_HI_EDU_CD', 'MOTHER_HI_EDU_CD','IN_STATE_FLAG',
        'FIRST_TERM_EARNED_HRS','SECOND_TERM_ATTEMPT_HRS','SECOND_TERM_EARNED_HRS',]].copy()

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
# Create a label encoder object
le = LabelEncoder()

# %% [markdown]
# Machine Learning algorithms can typically only have numerical values as their predictor variables. Hence Label Encoding becomes necessary as they encode categorical labels with numerical values

# %%
# Label Encoding will be used for columns with 2 or less unique values
le_count = 0
for col in stud1.columns[1:]:
    if stud1[col].dtype == 'object':
        if len(list(stud1[col].unique())) <= 2:
            le.fit(stud1[col])
            stud1[col] = le.transform(stud1[col])
            le_count += 1
print('{} columns were label encoded.'.format(le_count))
# Out:
# 3 columns were label encoded.

# %%
# convert rest of categorical variable into dummy
stud1 = pd.get_dummies(stud1, drop_first=True)

# %%
stud1.head(2)
# Out:
#    RETURNED_2ND_YR  UNMET_NEED  EST_FAM_CONTRIBUTION  DISTANCE_FROM_HOME  \
# 0                1         0.0                     0               150.0
# 1                0    459300.0                785760                69.0
#
#    STDNT_GENDER  STDNT_AGE  HOUSING_STS  HIGH_SCHL_GPA  FIRST_TERM  \
# 0             0         18            1           4.00      200708
# 1             0         19            0           2.89      200808
#
#    FATHER_HI_EDU_CD  ...  STDNT_MINOR_Music  STDNT_MINOR_N  \
# 0          2.560647  ...                  0              1
# 1          3.000000  ...                  0              1
#
#    STDNT_MINOR_Philosophy  STDNT_MINOR_Political Science  \
# 0                       0                              0
# 1                       0                              0
#
#    STDNT_MINOR_Professional Writing  STDNT_MINOR_Psychology  \
# 0                                 0                       0
# ...

# %%
stud1.isnull().sum()
# Out:
# RETURNED_2ND_YR                0
# UNMET_NEED                     0
# EST_FAM_CONTRIBUTION           0
# DISTANCE_FROM_HOME             0
# STDNT_GENDER                   0
#                               ..
# STDNT_MINOR_Psychology         0
# STDNT_MINOR_Sociology          0
# STDNT_MINOR_Spanish            0
# STDNT_MINOR_Theatre Arts       0
# STDNT_MINOR_Women's Studies    0
# Length: 104, dtype: int64

# %% [markdown]
# # Splitting data into training and testing sets

# %% [markdown]
# Prior to implementating or applying any Machine Learning algorithms, master dataframe must be decoupled into training and testing datasets.

# %% [markdown]
# The data we use is usually split into training data and test data. The training set contains a known output and the model learns on this data in order to be generalized to other data later on. We have the test dataset (or subset) in order to test our model's prediction on this subset . Train/test is used to measure the accuracy of model

# %%
X=stud1.drop("RETURNED_2ND_YR",axis=1)

# %%
y=stud1['RETURNED_2ND_YR']

# %%
X.head()
# Out:
#    UNMET_NEED  EST_FAM_CONTRIBUTION  DISTANCE_FROM_HOME  STDNT_GENDER  \
# 0         0.0                     0               150.0             0
# 1    459300.0                785760                69.0             0
# 2         0.0                     0               150.0             1
# 3         0.0                     0               150.0             1
# 4    278340.0                519840                69.0             0
#
#    STDNT_AGE  HOUSING_STS  HIGH_SCHL_GPA  FIRST_TERM  FATHER_HI_EDU_CD  \
# 0         18            1           4.00      200708          2.560647
# 1         19            0           2.89      200808          3.000000
# 2         18            1           3.39      201008          2.000000
# 3         18            1           2.93      200708          3.000000
# 4         18            0           3.86      200808          3.000000
#
#    MOTHER_HI_EDU_CD  ...  STDNT_MINOR_Music  STDNT_MINOR_N  \
# ...

# %%
# train and test are used to simulate the entire data..which will be used for building model for prediction
import sklearn.model_selection as model_selection
X_train,X_test,y_train,y_test=model_selection.train_test_split(X,y,test_size=0.3,random_state=7)

# %%
X_train.head()
# Out:
#       UNMET_NEED  EST_FAM_CONTRIBUTION  DISTANCE_FROM_HOME  STDNT_GENDER  \
# 2837   -231720.0                     0                 0.0             0
# 2337    461760.0                     0                 0.0             0
# 262    -356880.0                     0                 0.0             1
# 524          0.0                     0                 0.0             0
# 864          0.0                     0                69.0             0
#
#       STDNT_AGE  HOUSING_STS  HIGH_SCHL_GPA  FIRST_TERM  FATHER_HI_EDU_CD  \
# 2837         18            1           3.64      201008          4.000000
# 2337         18            0           3.13      200908          2.000000
# 262          18            0           3.73      200708          2.560647
# 524          18            1           2.61      200708          3.000000
# 864          18            0           3.30      200708          2.000000
#
#       MOTHER_HI_EDU_CD  ...  STDNT_MINOR_Music  STDNT_MINOR_N  \
# ...

# %%
y_train.head()
# Out:
# 2837    0
# 2337    1
# 262     1
# 524     0
# 864     0
# Name: RETURNED_2ND_YR, dtype: int64

# %% [markdown]
# # Building Machine Learning Models
#
# Let's first use a range of baseline algorithms (using out-of-the-box hyper-parameters) before we move on to more sophisticated solutions. The algorithms considered in this section are: Logistic Regression, Random Forest, Decision Tree Classifier, XGboost

# %%
import xgboost as XG

from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# sklearn modules for ML model selection
from sklearn.model_selection import train_test_split  # import 'train_test_split'
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# Libraries for data modelling
from sklearn import tree, linear_model
from sklearn import ensemble
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier

# Common sklearn Model Helpers
from sklearn import feature_selection
from sklearn import model_selection
from sklearn import metrics

# sklearn modules for performance metrics
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve
from sklearn.metrics import auc, roc_auc_score, roc_curve, recall_score, log_loss
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, make_scorer
from sklearn.metrics import average_precision_score
# Out:
# C:\Users\RetailAdmin\Anaconda3\lib\site-packages\dask\dataframe\utils.py:15: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# selection of algorithms to consider and set performance measure
models = []
models.append(('Logistic Regression', LogisticRegression(solver='liblinear', random_state=7,
                                                         class_weight='balanced')))
models.append(('Random Forest', RandomForestClassifier(
    n_estimators=100, random_state=7)))
models.append(('Decision Tree Classifier',
               DecisionTreeClassifier(random_state=7)))
models.append(('xgboost',
               XGBClassifier(random_state=7)))

# %%
acc_results = []
auc_results = []
names = []
# set table to table to populate with performance results
col = ['Algorithm', 'ROC AUC Mean', 'ROC AUC STD', 
       'Accuracy Mean', 'Accuracy STD']
df_results = pd.DataFrame(columns=col)
i = 0
# evaluate each model using cross-validation
for name, model in models:
    kfold = model_selection.KFold(
        n_splits=10, random_state=7)  # 10-fold cross-validation

    cv_acc_results = model_selection.cross_val_score(  # accuracy scoring
        model, X_train, y_train, cv=kfold, scoring='accuracy')

    cv_auc_results = model_selection.cross_val_score(  # roc_auc scoring
        model, X_train, y_train, cv=kfold, scoring='roc_auc')

    acc_results.append(cv_acc_results)
    auc_results.append(cv_auc_results)
    names.append(name)
    df_results.loc[i] = [name,
                         round(cv_auc_results.mean()*100, 2),
                         round(cv_auc_results.std()*100, 2),
                         round(cv_acc_results.mean()*100, 2),
                         round(cv_acc_results.std()*100, 2)
                         ]
    i += 1
df_results.sort_values(by=['ROC AUC Mean'], ascending=False)
# Out:
# C:\Users\RetailAdmin\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# C:\Users\RetailAdmin\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# C:\Users\RetailAdmin\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# ...

# %% [markdown]
# Classification Accuracy is the number of correct predictions made as a ratio of all predictions made. It is the most common evaluation metric for classification problems. However, it is often misused as it is only really suitable when there are an equal number of observations in each class and all predictions and prediction errors are equally important. It is not the case in this project, so a different scoring metric may be more suitable.

# %% [markdown]
# Using Scikit-Learn’s RandomizedSearchCV method, we can define a grid of hyperparameter ranges, and randomly sample from the grid, performing K-Fold CV with each combination of values.

# %%
fig = plt.figure(figsize=(15,7))
fig.suptitle('Algorithm Accuracy Comparison')
ax = fig.add_subplot(111)
plt.boxplot(acc_results)
ax.set_xticklabels(names)
plt.show()

# %% [markdown]
# Above box plot for all models shows the Accuracy comparison amongst each of them, Random forest and XGBOOST are at higher level, so for further analysis selecting these 2 models for the case study

# %%
fig = plt.figure(figsize=(15, 7))
fig.suptitle('Algorithm ROC AUC Comparison')
ax = fig.add_subplot(111)
plt.boxplot(auc_results)
ax.set_xticklabels(names)
plt.show()

# %% [markdown]
# Based on our ROC AUC comparison analysis, XGBoost and Random Forest show the highest mean AUC scores. We will shortlist these two algorithms for further analysis. See below for more details on these two algos

# %% [markdown]
# # Dealing with Imbalance

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# %%
X.shape
# Out:
# (5354, 103)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=7)
print(X.shape)
print(y.shape)
print('='*20)
print(X_train.shape)
print(y_train.shape)
print('='*20)
print(X_test.shape)
print(y_test.shape)
print('='*20)
# Out:
# (5354, 103)
# (5354,)
# ...
# (3747, 103)
# (3747,)
# ...
# (1607, 103)
# (1607,)
# ...

# %%
acc_results = []
auc_results = []
names = []
# set table to table to populate with performance results
col = ['Algorithm', 'ROC AUC Mean', 'ROC AUC STD', 
       'Accuracy Mean', 'Accuracy STD']
df_results = pd.DataFrame(columns=col)
i = 0
# evaluate each model using cross-validation
for name, model in models:
    kfold = model_selection.KFold(
        n_splits=10, random_state=7)  # 10-fold cross-validation

    cv_acc_results = model_selection.cross_val_score(  # accuracy scoring
        model, X_train, y_train, cv=kfold, scoring='accuracy')

    cv_auc_results = model_selection.cross_val_score(  # roc_auc scoring
        model, X_train, y_train, cv=kfold, scoring='roc_auc')

    acc_results.append(cv_acc_results)
    auc_results.append(cv_auc_results)
    names.append(name)
    df_results.loc[i] = [name,
                         round(cv_auc_results.mean()*100, 2),
                         round(cv_auc_results.std()*100, 2),
                         round(cv_acc_results.mean()*100, 2),
                         round(cv_acc_results.std()*100, 2)
                         ]
    i += 1
df_results.sort_values(by=['ROC AUC Mean'], ascending=False)
# Out:
# C:\Users\RetailAdmin\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# C:\Users\RetailAdmin\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# C:\Users\RetailAdmin\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# ...

# %% [markdown]
# # Random Forest Classifier
#
#     1.Random Forest is capable of solving both regression and classification. Random Forest is a brand of Ensemble
#       learning as it relies on an ensemble of decision trees.
#     2.Random Forest fits a number of decision tree classifiers on various sub-samples of the dataset and use averaging
#       to improve the predictive accuracy and control over-fitting.
#     3.Random Forest can handle a large number of features, and is helpful for estimating which of your variables are
#       important in the underlying data being modeled.
#
# Let's take a closer look at using the Random Forest algorithm. The Random Forest algorithm's hyper-parameters are fine tuned by cross-validation against the AUC score.

# %%
# parameters and ranges to plot
param_grid = {"n_estimators":[50, 75, 100, 125, 150, 175]}

# %%
rf_classifier= RandomForestClassifier(random_state=7,max_features='sqrt',class_weight='balanced_subsample')

# %%
# function takes a RF parameter dataframe of CV scores for parameter values
grid_obj= GridSearchCV(rf_classifier,param_grid=param_grid,n_jobs=-1,scoring='roc_auc',cv=10)
grid_obj.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=RandomForestClassifier(class_weight='balanced_subsample',
#                                               max_features='sqrt',
#                                               random_state=7),
#              n_jobs=-1,
#              param_grid={'n_estimators': [50, 75, 100, 125, 150, 175]},
#              scoring='roc_auc')

# %%
param_grid1 = {"max_depth": [5, 10, 15, 20, 25]}

# %%
grid_obj1 = GridSearchCV(rf_classifier, param_grid1,n_jobs=-1,scoring='roc_auc',cv=10)
grid_obj1.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=RandomForestClassifier(class_weight='balanced_subsample',
#                                               max_features='sqrt',
#                                               random_state=7),
#              n_jobs=-1, param_grid={'max_depth': [5, 10, 15, 20, 25]},
#              scoring='roc_auc')

# %%
param_grid2 = {"min_samples_split": [2,4,6,8,10]}

# %%
grid_obj2 = GridSearchCV(rf_classifier, param_grid2,n_jobs=-1,scoring='roc_auc',cv=10)
grid_obj2.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=RandomForestClassifier(class_weight='balanced_subsample',
#                                               max_features='sqrt',
#                                               random_state=7),
#              n_jobs=-1, param_grid={'min_samples_split': [2, 4, 6, 8, 10]},
#              scoring='roc_auc')

# %%
param_grid3 = { "min_samples_leaf": [1, 2, 3, 4] }

# %%
grid_obj3 = GridSearchCV(rf_classifier, param_grid3,n_jobs=-1,scoring='roc_auc',cv=10)
grid_obj3.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=RandomForestClassifier(class_weight='balanced_subsample',
#                                               max_features='sqrt',
#                                               random_state=7),
#              n_jobs=-1, param_grid={'min_samples_leaf': [1, 2, 3, 4]},
#              scoring='roc_auc')

# %%
print(grid_obj.best_params_)
print(grid_obj1.best_params_)
print(grid_obj2.best_params_)
print(grid_obj3.best_params_)
# Out:
# {'n_estimators': 175}
# {'max_depth': 25}
# {'min_samples_split': 2}
# {'min_samples_leaf': 1}

# %%
print(grid_obj.best_score_)
# Out:
# 0.9262342238688005

# %% [markdown]
# As shown above, the results from GridSearchCV provided us with fine-tuned hyper-parameter using ROC_AUC as the scoring metric
#
# Best score --0.93 shows the prediction accuracy for this model.
# It is achieved by performing Grid Search based on the estimators.

# %%
plt.figure(figsize=(10,5))
plt.plot(grid_obj.cv_results_['mean_test_score'])

# %%
grid_fit = RandomForestClassifier(random_state=7,max_features='sqrt',class_weight='balanced_subsample',
                                        n_estimators= 175,
                                        max_depth= 25,
                                        min_samples_split= 2,
                                        min_samples_leaf= 1)

# %%
grid_fit.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced_subsample', max_depth=25,
#                        max_features='sqrt', n_estimators=175, random_state=7)

# %%
importances = grid_fit.feature_importances_
indices = np.argsort(importances)[::-1] # Sort feature importances in descending order
names = [X_train.columns[i] for i in indices] # Rearrange feature names so they match the sorted feature importances
plt.figure(figsize=(40,7)) # Create plot
plt.title("Feature Importance") # Create plot title
plt.bar(range(X_train.shape[1]), importances[indices]) # Add bars
plt.xticks(range(X_train.shape[1]), names, rotation=90) # Add feature names as x-axis labels
plt.show() # Show plot

# %% [markdown]
# Random Forest helped us identify the Top 10 most important indicators (ranked in the table above) as: Second term attempt hours ,Second term earned hours,Mother higher education,High school GPA,Father higher education,Distance from home,first term earned hours,Unmet needs, First term, Family contribution

# %% [markdown]
# # Evaluation of RF model

# %%
# Confusion Matrix
cnf_matrix = metrics.confusion_matrix(y_test, grid_fit.predict(X_test))
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %% [markdown]
# Confusion Matrix:
# A confusion matrix is a summary of prediction results on a classification problem. The number of correct and incorrect predictions are summarized with count values and broken down by each class. This is the key to the confusion matrix. The confusion matrix shows the ways in which your classification model is confused when it makes predictions. It gives us insight not only into the errors being made by a classifier but more importantly the types of errors that are being made.
#
# The confusion matrix is useful for giving you false positives and false negatives. The classification report tells you the accuracy of your model.
#
# `Classification Rate/Accuracy`:The classification report tells you the accuracy of your model.
#
# Accuracy = (TP + TN) / (TP + TN + FP + FN) = (664 + 754) /(664 + 754 + 51 + 138) = 0.882
#
# `Recall`: Recall gives us an idea about when it’s actually yes, how often does it predict yes.
#
# Recall = TP / (TP + FN) = 664/ (664 + 138) = 0.827
#
# `Precision`: Precsion tells us about when it predicts yes, how often is it correct.
#
# Precision = TP / (TP + FP)=664/ (664+51) = 0.928
#
# `F-measure`:
#
# Fmeasure = (2 * Recall * Precision) / (Recall + Presision) = (2 * 0.827 * 0.928) / (0.827 + 0.928) = 0.874

# %%
print('Accuracy of RandomForest Regression Classifier on test set: {:.2f}'.format(grid_fit.score(X_test, y_test)*100))
# Out:
# Accuracy of RandomForest Regression Classifier on test set: 88.24

# %% [markdown]
# The Confusion matrix is telling us that we have 754+664 correct predictions and 51+138 incorrect predictions. In other words, an accuracy of 88.24%.

# %%
# Classification report for the optimised RF Regression
grid_fit.fit(X_train, y_train)
print(classification_report(y_test, grid_fit.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89       805
#            1       0.93      0.83      0.88       802
#
#     accuracy                           0.88      1607
#    macro avg       0.89      0.88      0.88      1607
# weighted avg       0.89      0.88      0.88      1607

# %%
grid_fit.fit(X_train, y_train) # fit optimised model to the training data
probs = grid_fit.predict_proba(X_test) # predict probabilities
probs = probs[:, 1] # we will only keep probabilities associated with the employee leaving
grid_fit_roc_auc = roc_auc_score(y_test, probs) # calculate AUC score using test dataset
print('AUC score: %.3f' % grid_fit_roc_auc)
# Out:
# AUC score: 0.930

# %% [markdown]
# AUC provides an aggregate measure of performance across all possible classification thresholds. One way of interpreting AUC is as the probability that the model ranks a random positive example more highly than a random negative example.

# %%
fpr, tpr, thresholds = roc_curve(y_test,grid_fit.predict_proba(X_test)[:,1]) 
plt.figure()
plt.plot(fpr, tpr, label='Model (Area = %0.2f)' % grid_fit_roc_auc) 
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.savefig('RANDOM FOREST')
plt.show()

# %% [markdown]
# # XGBOOST
#
# XGBoost is an implementation of gradient boosted decision trees designed for speed and performance that is dominative competitive machine learning.
#
# The two reasons to use XGBoost are also the two goals of the project: Execution Speed. Model Performance.

# %% [markdown]
# XGBoost Execution Speed- Generally, XGBoost is fast. Really fast when compared to other            implementations of gradient boosting.
#
# XGBoost Model Performance- XGBoost dominates structured or tabular datasets on
# classification and regression predictive modeling problems.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from operator import itemgetter
import xgboost as xgb
import random
import time
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import average_precision_score
import matplotlib.pyplot as plt
from numpy import genfromtxt
import seaborn as sns
from sklearn import preprocessing
from sklearn.metrics import roc_curve, auc,recall_score,precision_score
import datetime as dt

# %%
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV
import time
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve

# %%
#The StandardScaler assumes your data is normally distributed within each feature and will scale them such 
steps = [('scaler', StandardScaler()), ('XGBoost', xgb.XGBClassifier())]

# %%
#The purpose of the pipeline is to assemble several steps that can be cross-validated together while setting different parameters. For this, it enables setting parameters of the various steps using their names and the parameter name
pipeline = Pipeline(steps)

# %%
parameters = {'XGBoost__booster': ['gbtree', 'gblinear', 'dart'],
              'XGBoost__subsample': np.arange(0.5, 1, 0.05),
              'XGBoost__max_depth': np.arange(3, 20, 1),
              'XGBoost__colsample_bytree': np.arange(0.1, 1.05, 0.05),
              'XGBoost__objective': ['reg:logistic','binary:logistic']}
# reg:logostic and binary: logistic will give the output in probability form and not is class 1 or 0

# %%
# Building model
model = RandomizedSearchCV(pipeline, parameters, n_iter=10, scoring='roc_auc', cv=4)

# %%
start_time = time.time()

# %%
model.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=4,
#                    estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                              ('XGBoost',
#                                               XGBClassifier(base_score=None,
#                                                             booster=None,
#                                                             colsample_bylevel=None,
#                                                             colsample_bynode=None,
#                                                             colsample_bytree=None,
#                                                             gamma=None,
#                                                             gpu_id=None,
#                                                             importance_type='gain',
#                                                             interaction_constraints=None,
#                                                             learning_rate=None,
# ...

# %%
elapsed_time = (time.time() - start_time)/60
print('Time to tune the model: {0:0.2f} min.'.format(elapsed_time))
# Out:
# Time to tune the model: 1.80 min.

# %%
print('Tuned Model Parameters: {}'.format(model.best_params_))
# Out:
# Tuned Model Parameters: {'XGBoost__subsample': 0.6000000000000001, 'XGBoost__objective': 'binary:logistic', 'XGBoost__max_depth': 17, 'XGBoost__colsample_bytree': 0.6500000000000001, 'XGBoost__booster': 'dart'}

# %%
#To make predictions we use the scikit-learn function model. predict(). By default, the predictions made by XGBoost are probabilities.
predictions = model.predict(X_test)

# %%
pred_prob = model.predict_proba(X_test)[:,1]

# %%
cm = pd.DataFrame(confusion_matrix(y_test, predictions))
cm['Total'] = np.sum(cm, axis=1)
cm = cm.append(np.sum(cm, axis=0), ignore_index=True)
cm.columns = ['Predicted No', 'Predicted Yes', 'Total']
cm = cm.set_index([['Actual No', 'Actual Yes', 'Total']])
print(cm)
# Out:
#             Predicted No  Predicted Yes  Total
# Actual No            739             66    805
# Actual Yes           136            666    802
# Total                875            732   1607

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88       805
#            1       0.91      0.83      0.87       802
#
#     accuracy                           0.87      1607
#    macro avg       0.88      0.87      0.87      1607
# weighted avg       0.88      0.87      0.87      1607

# %%
logit_roc_auc = roc_auc_score(y_test, model.predict(X_test))

# %%
print('AUC score: %.3f' % logit_roc_auc)
# Out:
# AUC score: 0.874

# %%
fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:,1]) 
plt.figure()
plt.plot(fpr, tpr, label='Model (Area = %0.2f)' % logit_roc_auc) 
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.savefig('XGBoost_ROC')
plt.show()

# %%
# Create ROC Graph
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:,1])
rf_fpr, rf_tpr, rf_thresholds = roc_curve(y_test, grid_fit.predict_proba(X_test)[:,1])
plt.figure(figsize=(14, 6))

# Plot XGboost ROC
plt.plot(fpr, tpr, label='XGBoost (area = %0.2f)' % logit_roc_auc)
# Plot Random Forest ROC
plt.plot(rf_fpr, rf_tpr, label='Random Forest (area = %0.2f)' % grid_fit_roc_auc)
# Plot Base Rate ROC
plt.plot([0,1], [0,1],label='Base Rate' 'k--')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Graph')
plt.legend(loc="lower right")
plt.show()
